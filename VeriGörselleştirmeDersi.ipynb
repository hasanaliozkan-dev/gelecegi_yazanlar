# %%
import seaborn as sns

# %%
planets = sns.load_dataset("planets")

# %%
df = planets.copy()

# %%
df.describe().T
# Out:
#                  count         mean  ...       75%       max
# number          1035.0     1.785507  ...     2.000       7.0
# orbital_period   992.0  2002.917596  ...   526.005  730000.0
# mass             513.0     2.638161  ...     3.040      25.0
# distance         808.0   264.069282  ...   178.500    8500.0
# year            1035.0  2009.070531  ...  2012.000    2014.0
#
# [5 rows x 8 columns]

# %%
df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   method          1035 non-null   object
#  1   number          1035 non-null   int64
#  2   orbital_period  992 non-null    float64
#  3   mass            513 non-null    float64
#  4   distance        808 non-null    float64
#  5   year            1035 non-null   int64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 48.6+ KB

# %%
import pandas as pd
df.method = pd.Categorical(df.method)

# %%
df.describe().T
# Out:
#                  count         mean  ...       75%       max
# number          1035.0     1.785507  ...     2.000       7.0
# orbital_period   992.0  2002.917596  ...   526.005  730000.0
# mass             513.0     2.638161  ...     3.040      25.0
# distance         808.0   264.069282  ...   178.500    8500.0
# year            1035.0  2009.070531  ...  2012.000    2014.0
#
# [5 rows x 8 columns]

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.isnull().sum()
# Out:
# method              0
# number              0
# orbital_period     43
# mass              522
# distance          227
# year                0
# dtype: int64

# %%
cate_var = df.select_dtypes(include= ["category"])

# %%
cate_var
# Out:
#                method
# 0     Radial Velocity
# 1     Radial Velocity
# 2     Radial Velocity
# 3     Radial Velocity
# 4     Radial Velocity
# ...               ...
# 1030          Transit
# 1031          Transit
# 1032          Transit
# 1033          Transit
# 1034          Transit
#
# [1035 rows x 1 columns]

# %%
cate_var.method.unique()
# Out:
# ['Radial Velocity', 'Imaging', 'Eclipse Timing Variations', 'Transit', 'Astrometry', 'Transit Timing Variations', 'Orbital Brightness Modulation', 'Microlensing', 'Pulsar Timing', 'Pulsation Timing Variations']
# Categories (10, object): ['Radial Velocity', 'Imaging', 'Eclipse Timing Variations', 'Transit', ...,
#                           'Orbital Brightness Modulation', 'Microlensing', 'Pulsar Timing',
#                           'Pulsation Timing Variations']

# %%
cate_var.method.value_counts().count()
# Out:
# 10

# %%
cate_var.method.value_counts()
cate_var.method.unique()
# Out:
# ['Radial Velocity', 'Imaging', 'Eclipse Timing Variations', 'Transit', 'Astrometry', 'Transit Timing Variations', 'Orbital Brightness Modulation', 'Microlensing', 'Pulsar Timing', 'Pulsation Timing Variations']
# Categories (10, object): ['Radial Velocity', 'Imaging', 'Eclipse Timing Variations', 'Transit', ...,
#                           'Orbital Brightness Modulation', 'Microlensing', 'Pulsar Timing',
#                           'Pulsation Timing Variations']

# %%
cate_var.count()
# Out:
# method    1035
# dtype: int64

# %%
cate_var.method.value_counts().plot.barh();

# %%
num_var = df.select_dtypes(include=["float64","int64"]) 
num_var
# Out:
# method            category
# number               int64
# orbital_period     float64
# mass               float64
# distance           float64
# year                 int64
# dtype: object

# %%
print("Ortalama : " + str(num_var.distance.mean()))
print("Dolu gözlem sayısı : " + str(num_var.distance.count()))
print("Boş gözlem sayısı : " + str(len(num_var[num_var.distance.isnull()==True])))
print("Maximum değer  : " + str(num_var.distance.max()))
print("Minimum değer  : " + str(num_var.distance.min()))
print("Medyan : " + str(df.distance.median()))
print("Standart Sapma : " + str(df.distance.std()))
# Out:
# Ortalama : 264.06928217821786
# Dolu gözlem sayısı : 808
# Boş gözlem sayısı : 227
# Maximum değer  : 8500.0
# Minimum değer  : 1.35
# Medyan : 55.25
# Standart Sapma : 733.1164929404422

# %%
print()

# %%
import seaborn as sns

# %%
diamonds = sns.load_dataset("diamonds")

# %%
df = diamonds.copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  category
#  2   color    53940 non-null  category
#  3   clarity  53940 non-null  category
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: category(3), float64(6), int64(1)
# memory usage: 3.0 MB

# %%
df.describe().T
# Out:
#          count         mean          std  ...      50%      75%       max
# carat  53940.0     0.797940     0.474011  ...     0.70     1.04      5.01
# depth  53940.0    61.749405     1.432621  ...    61.80    62.50     79.00
# table  53940.0    57.457184     2.234491  ...    57.00    59.00     95.00
# price  53940.0  3932.799722  3989.439738  ...  2401.00  5324.25  18823.00
# x      53940.0     5.731157     1.121761  ...     5.70     6.54     10.74
# y      53940.0     5.734526     1.142135  ...     5.71     6.54     58.90
# z      53940.0     3.538734     0.705699  ...     3.53     4.04     31.80
#
# [7 rows x 8 columns]

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df.cut.value_counts()
# Out:
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: cut, dtype: int64

# %%
df.color.value_counts()
# Out:
# G    11292
# E     9797
# F     9542
# H     8304
# D     6775
# I     5422
# J     2808
# Name: color, dtype: int64

# %%
df.clarity.value_counts()
# Out:
# SI1     13065
# VS2     12258
# SI2      9194
# VS1      8171
# VVS2     5066
# VVS1     3655
# IF       1790
# I1        741
# Name: clarity, dtype: int64

# %%
cut_categories = ["Fair","Good","Very Good","Premium","Ideal"]

# %%
from pandas.api.types import CategoricalDtype
df.cut = df.cut.astype(CategoricalDtype(ordered=True,categories=cut_categories))

# %%
df.dtypes
# Out:
# carat       float64
# cut        category
# color      category
# clarity    category
# depth       float64
# table       float64
# price         int64
# x           float64
# y           float64
# z           float64
# dtype: object

# %%
df.cut.head(1)
# Out:
# 0    Ideal
# Name: cut, dtype: category
# Categories (5, object): ['Fair' < 'Good' < 'Very Good' < 'Premium' < 'Ideal']

# %%
df.cut.value_counts().plot.barh().set_title("Categorical frequency of cut values");

# %%
(df.cut
 .value_counts()
 .plot.barh()
 .set_title("Categorical frequency of cut values"));

# %%
sns.barplot(x=df.cut ,y = df.cut.index ,data = df)

# %%
 df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.catplot(x="cut",y="price",data=df);

# %%
sns.barplot(x="cut",y="price",hue="color",data=df);

# %%
df.groupby(["cut","color"])["price"].mean()
# Out:
# cut        color
# Fair       D        4291.061350
#            E        3682.312500
#            F        3827.003205
#            G        4239.254777
#            H        5135.683168
#            I        4685.445714
#            J        4975.655462
# Good       D        3405.382175
#            E        3423.644159
#            F        3495.750275
#            G        4123.482204
#            H        4276.254986
#            I        5078.532567
#            J        4574.172638
# Very Good  D        3470.467284
#            E        3214.652083
#            F        3778.820240
#            G        3872.753806
#            H        4535.390351
#            I        5255.879568
#            J        5103.513274
# Premium    D        3631.292576
#            E        3538.914420
#            F        4324.890176
#            G        4500.742134
#            H        5216.706780
#            I        5946.180672
#            J        6294.591584
# ...

# %%
sns.distplot(df.price,kde=False,bins=10);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df.price);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df.price,hist=False);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
df.price.describe()
# Out:
# count    53940.000000
# mean      3932.799722
# std       3989.439738
# min        326.000000
# 25%        950.000000
# 50%       2401.000000
# 75%       5324.250000
# max      18823.000000
# Name: price, dtype: float64

# %%
sns.kdeplot(df.price,shade=True)

# %%
(sns
 .FacetGrid(df,
               hue="cut",
               height=5,
               xlim= (0,10000))
 .map(sns.kdeplot,"price",shade=True)
 .add_legend());

# %%
sns.catplot(x="cut",y="price",hue="color",kind="point",data=df)

# %%
import seaborn as sns 
tips = sns.load_dataset("tips")
df = tips.copy()
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.describe().T
# Out:
#             count       mean       std   min      25%     50%      75%    max
# total_bill  244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275  50.81
# tip         244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625  10.00
# size        244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000   6.00

# %%
df["sex"].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
df["smoker"].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
df["day"].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
df["time"].value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
sns.boxplot(x=df.total_bill);

# %%
sns.boxplot(y = df.total_bill , orient="v")

# %%
df.describe().T
# Out:
#             count       mean       std   min      25%     50%      75%    max
# total_bill  244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275  50.81
# tip         244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625  10.00
# size        244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000   6.00

# %%
#Hangi günler daha fazla kazanıyoruz
sns.boxplot(x="day",y="total_bill",data=df);

# %%
#sabah mı akşam mı daha fazla kazanıyoruz
sns.boxplot(x="time",y="total_bill",data=df);

# %%
#kişi sayısı kazanç
sns.boxplot(x="size",y="total_bill",data=df);

# %%
sns.boxplot(x="day",y="total_bill",hue="sex",data=df);

# %%
sns.catplot(y="total_bill",kind="violin",data=df);

# %%
sns.catplot(x="day" , y="total_bill",kind="violin",data=df);

# %%
sns.catplot(x="day" , y="total_bill",kind="violin",hue="sex",data=df);

# %%
sns.scatterplot(x="total_bill",y="tip",data=df);

# %%
sns.scatterplot(x="total_bill",y="tip",hue="time",data=df);

# %%
sns.scatterplot(x="total_bill",y="tip",hue="day",style="time",data=df);

# %%
sns.scatterplot(x="total_bill",y="tip",hue="size",size="size",data=df);

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.lmplot(x="total_bill",y="tip",data=df);

# %%
sns.lmplot(x="total_bill",y="tip",hue="smoker",data=df);

# %%
sns.lmplot(x="total_bill",y="tip",hue="sex",data=df);

# %%
sns.lmplot(x="total_bill",y="tip",hue="smoker",col="time",data=df);

# %%
sns.lmplot(x="total_bill",y="tip",hue="sex",col="time",data=df);

# %%
sns.lmplot(x="total_bill",y="tip",hue="smoker",col="sex",data=df);

# %%
sns.lmplot(x="total_bill",y="tip",hue="smoker",col="time",row="sex",data=df);

# %%
import seaborn as sns
iris= sns.load_dataset("iris")
df = iris.copy()
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
df.shape
# Out:
# (150, 5)

# %%
sns.pairplot(df);

# %%
sns.pairplot(df,hue="species");

# %%
sns.pairplot(df,hue="species",markers=["o","s","D"]);

# %%
sns.pairplot(df,kind="reg");

# %%
sns.pairplot(df,hue="species",kind="reg");

# %%
import seaborn as sns
flights = sns.load_dataset("flights")
df = flights.copy()
df.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
df.dtypes
# Out:
# year             int64
# month         category
# passengers       int64
# dtype: object

# %%
df.describe().T
# Out:
#             count         mean         std  ...     50%      75%     max
# year        144.0  1954.500000    3.464102  ...  1954.5  1957.25  1960.0
# passengers  144.0   280.298611  119.966317  ...   265.5   360.50   622.0
#
# [2 rows x 8 columns]

# %%
df.passengers.describe()
# Out:
# count    144.000000
# mean     280.298611
# std      119.966317
# min      104.000000
# 25%      180.000000
# 50%      265.500000
# 75%      360.500000
# max      622.000000
# Name: passengers, dtype: float64

# %%
df= df.pivot("month","year","passengers")
df
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
sns.heatmap(df);

# %%
sns.heatmap(df,annot=True,fmt="d");

# %%
sns.heatmap(df,annot=True,fmt="d",linewidths=.5);

# %%
sns.heatmap(df,annot=True,fmt="d",linewidths=.5,cbar=False);

# %%
import seaborn as sns 
fmri = sns.load_dataset("fmri")
df = fmri.copy()
df.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
df.shape
# Out:
# (1064, 5)

# %%
df.timepoint.describe()
# Out:
# count    1064.000000
# mean        9.000000
# std         5.479801
# min         0.000000
# 25%         4.000000
# 50%         9.000000
# 75%        14.000000
# max        18.000000
# Name: timepoint, dtype: float64

# %%
df.signal.describe()
# Out:
# count    1064.000000
# mean        0.003540
# std         0.093930
# min        -0.255486
# 25%        -0.046070
# 50%        -0.013653
# 75%         0.024293
# max         0.564985
# Name: signal, dtype: float64

# %%
df.groupby("timepoint")["signal"].count()#her bir zaman noktasında eşit sinyal sayılmış
# Out:
# timepoint
# 0     56
# 1     56
# 2     56
# 3     56
# 4     56
# 5     56
# 6     56
# 7     56
# 8     56
# 9     56
# 10    56
# 11    56
# 12    56
# 13    56
# 14    56
# 15    56
# 16    56
# 17    56
# 18    56
# Name: signal, dtype: int64

# %%
df.groupby("signal").count()
# Out:
#            subject  timepoint  event  region
# signal
# -0.255486        1          1      1       1
# -0.238474        1          1      1       1
# -0.224351        1          1      1       1
# -0.181241        1          1      1       1
# -0.178510        1          1      1       1
# ...            ...        ...    ...     ...
#  0.455575        1          1      1       1
#  0.460896        1          1      1       1
#  0.476055        1          1      1       1
#  0.494787        1          1      1       1
#  0.564985        1          1      1       1
#
# [1064 rows x 4 columns]

# %%
df.groupby("timepoint")["signal"].describe()
# Out:
#            count      mean       std  ...       50%       75%       max
# timepoint                             ...
# 0           56.0 -0.016662  0.028326  ... -0.018382  0.003539  0.074399
# 1           56.0 -0.025002  0.030641  ... -0.024533 -0.005388  0.063558
# 2           56.0 -0.012873  0.035440  ... -0.013183  0.009318  0.077277
# 3           56.0  0.034446  0.058260  ...  0.028430  0.061840  0.185581
# 4           56.0  0.098194  0.092838  ...  0.070166  0.144911  0.346775
# 5           56.0  0.137725  0.123353  ...  0.096535  0.211638  0.476055
# 6           56.0  0.127515  0.137332  ...  0.068850  0.218919  0.564985
# 7           56.0  0.075660  0.129704  ...  0.032486  0.144781  0.494787
# 8           56.0  0.013420  0.104216  ... -0.012834  0.030396  0.337143
# 9           56.0 -0.032041  0.072728  ... -0.038496  0.008717  0.221716
# 10          56.0 -0.053685  0.053148  ... -0.052906 -0.015302  0.089231
# ...

# %%
sns.lineplot(x="timepoint",y="signal",data=df);

# %%
sns.lineplot(x="timepoint",y="signal",hue="event",data=df);

# %%
sns.lineplot(x="timepoint",y="signal",hue="event",style="event",data=df);

# %%
sns.lineplot(x="timepoint",y="signal",hue="event",style="event",markers=True,dashes=False,data=df);

# %%
sns.lineplot(x="timepoint",y="signal",hue="region",style="event",data=df);

# %%
import pandas_datareader as pr

# %%
df = pr.get_data_yahoo("AAPL",start="2016-01-01",end="2019-08-25")

# %%
df.head()
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2016-01-04  26.342501  25.500000  25.652500  26.337500  270597600.0  24.323219
# 2016-01-05  26.462500  25.602501  26.437500  25.677500  223164000.0  23.713696
# 2016-01-06  25.592501  24.967501  25.139999  25.174999  273829600.0  23.249626
# 2016-01-07  25.032499  24.107500  24.670000  24.112499  324377600.0  22.268383
# 2016-01-08  24.777500  24.190001  24.637501  24.240000  283192000.0  22.386133

# %%
df.shape
# Out:
# (917, 6)

# %%
close = df.Close

# %%
close.plot();

# %%
close.index
# Out:
# DatetimeIndex(['2016-01-04', '2016-01-05', '2016-01-06', '2016-01-07',
#                '2016-01-08', '2016-01-11', '2016-01-12', '2016-01-13',
#                '2016-01-14', '2016-01-15',
#                ...
#                '2019-08-12', '2019-08-13', '2019-08-14', '2019-08-15',
#                '2019-08-16', '2019-08-19', '2019-08-20', '2019-08-21',
#                '2019-08-22', '2019-08-23'],
#               dtype='datetime64[ns]', name='Date', length=917, freq=None)

# %%
import pandas as pd
close.index=pd.DatetimeIndex(close.index)

# %%
close.plot();

# %%
# ?sns.distplot
