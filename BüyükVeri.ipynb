# %%
import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)
warnings.filterwarnings("ignore",category=FutureWarning)

# %%
# !pip install findspark

# %%
import findspark
findspark.init("/Users/hasanaliozkan/spark/spark-3.1.2-bin-hadoop3.2")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/findspark.py in init(spark_home, python_path, edit_rc, edit_profile)
#     142     try:
# --> 143         py4j = glob(os.path.join(spark_python, "lib", "py4j-*.zip"))[0]
#     144     except IndexError:
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-3-ddace7405547> in <module>()
#       1 import findspark
# ----> 2 findspark.init("/Users/hasanaliozkan/spark/spark-3.1.2-bin-hadoop3.2")
#
# /usr/local/lib/python3.7/dist-packages/findspark.py in init(spark_home, python_path, edit_rc, edit_profile)
#     144     except IndexError:
#     145         raise Exception(
# ...
