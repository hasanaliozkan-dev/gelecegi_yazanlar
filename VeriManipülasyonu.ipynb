# %%
import numpy as np 
np.ones((2,3))
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %%
import numpy as np
import pandas as pd
m = np.arange(1,7).reshape((3,2))
df1 = pd.DataFrame(m, columns = ["var1","var2"])

# %%
df2 = df1 + 99

# %%
df2
# Out:
#    var1  var2
# 0   100   101
# 1   102   103
# 2   104   105

# %%
seri = pd.Series()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   """Entry point for launching an IPython kernel.

# %%
denem = seri.values

# %%
type(denem)
# Out:
# numpy.ndarray

# %%
seri = pd.Series([121,200,150,99],  index = ["reg","loj","cart","rf"])

# %%
df1.groupby("gruplar").agg({"degisken1": "max", "degisken2": "min"})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-8417aba038ed> in <module>()
# ----> 1 df1.groupby("gruplar").agg({"degisken1": "max", "degisken2": "min"})
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6523             squeeze=squeeze,
#    6524             observed=observed,
# -> 6525             dropna=dropna,
#    6526         )
#    6527
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     531                 observed=observed,
#     532                 mutated=self.mutated,
# --> 533                 dropna=self.dropna,
#     534             )
#     535
#
# ...

# %%
df1.loc[3,4]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     354                 try:
# --> 355                     return self._range.index(new_key)
#     356                 except ValueError as err:
#
# ValueError: 3 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-280e0e27ddbb> in <module>()
# ----> 1 df1.loc[3,4]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
# ...

# %%
df1.tail(3)
# Out:
#    var1  var2
# 0     1     2
# 1     3     4
# 2     5     6

# %%
df1.describe()
# Out:
#        var1  var2
# count   3.0   3.0
# mean    3.0   4.0
# std     2.0   2.0
# min     1.0   2.0
# 25%     2.0   3.0
# 50%     3.0   4.0
# 75%     4.0   5.0
# max     5.0   6.0

# %%
df2 = df1

# %%
pd.merge(df1,df2,on="var1")
# Out:
#    var1  var2_x  var2_y
# 0     1       2       2
# 1     3       4       4
# 2     5       6       6

# %%
seri = pd.Series([121,200,150,99])

seri.values
# Out:
# array([121, 200, 150,  99])

# %%
type(df1.groupby("var1"))
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
df1.groupby("var1")

# %%
df1.var()
# Out:
# var1    4.0
# var2    4.0
# dtype: float64

# %%
df1.count()
# Out:
# var1    3
# var2    3
# dtype: int64

# %%
df1.std()
# Out:
# var1    2.0
# var2    2.0
# dtype: float64

# %%
df1.median()
# Out:
# var1    3.0
# var2    4.0
# dtype: float64

# %%
df1.ndim
# Out:
# 2

# %%
seri.dtype
# Out:
# dtype('int64')

# %%
df1.describe()
# Out:
#        var1  var2
# count   3.0   3.0
# mean    3.0   4.0
# std     2.0   2.0
# min     1.0   2.0
# 25%     2.0   3.0
# 50%     3.0   4.0
# 75%     4.0   5.0
# max     5.0   6.0

# %%
import numpy as np
import pandas as pd
m = np.random.randint(1,30, size = (10,3))
df = pd.DataFrame(m, columns = ["var1","var2","var3"])
df
# Out:
#    var1  var2  var3
# 0    25    25    22
# 1    24    22     7
# 2    23     6    16
# 3    19    15    24
# 4    23    17     6
# 5    10    12    19
# 6    23    18    28
# 7    16    17    12
# 8     8    11    27
# 9     5     3    12
