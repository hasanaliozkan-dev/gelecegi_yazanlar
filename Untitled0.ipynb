# %%
import http.client

conn = http.client.HTTPSConnection("api.collectapi.com")

headers = {
    'content-type': "application/json",
    'authorization': "apikey 7GHo8Z9IeTjQDCmcQ1f1wP:6rUviSLFXKS5xAPW3IV0MU"
    }

conn.request("GET", "/weather/getWeather?data.lang=tr&data.city=mugla", headers=headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {"success":true,"city":"mugla","result":[{"date":"02.08.2021","day":"Pazartesi","icon":"https://image.flaticon.com/icons/svg/143/143769.svg","description":"açık","status":"Clear","degree":"34.53","min":"21.35","max":"36.79","night":"29.04","humidity":"10"},{"date":"03.08.2021","day":"Salı","icon":"https://image.flaticon.com/icons/svg/143/143769.svg","description":"açık","status":"Clear","degree":"38.15","min":"21.57","max":"38.82","night":"26.96","humidity":"10"},{"date":"04.08.2021","day":"Çarşamba","icon":"https://image.flaticon.com/icons/svg/143/143769.svg","description":"açık","status":"Clear","degree":"37.47","min":"24.09","max":"39.34","night":"27.6","humidity":"12"},{"date":"05.08.2021","day":"Perşembe","icon":"https://image.flaticon.com/icons/svg/143/143769.svg","description":"açık","status":"Clear","degree":"37.25","min":"23.19","max":"37.83","night":"26.64","humidity":"13"},{"date":"06.08.2021","day":"Cuma","icon":"https://image.flaticon.com/icons/svg/143/143769.svg","descr
# ...
